# %% [markdown]
# # Sets y modificaciones

# %%
set_countries = {'col', 'mex', 'bol', 'col'}
size_set_countries = len(set_countries)
print(set_countries)
print(type(set_countries))
print(size_set_countries)
print('col' in set_countries)
print('pe' in set_countries)

# add Peru a set_countries
set_countries.add('pe')
print(set_countries)
set_countries.add('pe')
print(set_countries)

# update
set_countries.update({'ar', 'ecua', 'pe'})
print(set_countries)

# remove
set_countries.remove('col')
print(set_countries)
set_countries.remove('ar')
print(set_countries)
set_countries.discard('arg')
print(set_countries)
set_countries.clear()
print(set_countries)
print(len(set_countries))
# Out:
# {'bol', 'col', 'mex'}
# <class 'set'>
# 3
# True
# False
# {'bol', 'pe', 'col', 'mex'}
# {'bol', 'pe', 'col', 'mex'}
# {'ar', 'bol', 'ecua', 'pe', 'col', 'mex'}
# {'ar', 'bol', 'ecua', 'pe', 'mex'}
# {'bol', 'ecua', 'pe', 'mex'}
# {'bol', 'ecua', 'pe', 'mex'}
# set()
# 0

# %%
set_numbers = {1, 2, 2, 443, 23}
print(set_numbers)
# Out:
# {1, 2, 443, 23}

# %%
set_types = {1, 'hola', False, 12.12}
print(set_types)
# Out:
# {False, 1, 'hola', 12.12}

# %%
set_from_string = set('hoolaaa')
print(set_from_string)
# Out:
# {'o', 'l', 'h', 'a'}

# %%
set_from_tuples = set(('abc', 'cbv', 'as', 'abc'))
print(set_from_tuples)
# Out:
# {'as', 'cbv', 'abc'}

# %%
numbers = [1,2,3,1,2,3,4]
set_numbers_from_list = set(numbers)
print(set_numbers_from_list)
unique_numbers = list(set_numbers_from_list)
print(unique_numbers)
# Out:
# {1, 2, 3, 4}
# [1, 2, 3, 4]

# %% [markdown]
# # Operaciones con sets (conjuntos)

# %%
set_a = {'col', 'mex', 'bol'}
set_b = {'pe', 'bol'}

# suma
set_c = set_a.union(set_b)
print(set_c)
print(set_a | set_b)

# interseccion

set_c = set_a.intersection(set_b)
print(set_c)
print(set_a & set_b)

# diferencia

set_c = set_a.difference(set_b)
print(set_c)
print(set_a - set_b)

# diferencia simetrica

set_c = set_a.symmetric_difference(set_b)
print(set_c)
print(set_a ^ set_b)
# Out:
# {'bol', 'pe', 'col', 'mex'}
# {'bol', 'pe', 'col', 'mex'}
# {'bol'}
# {'bol'}
# {'col', 'mex'}
# {'col', 'mex'}
# {'pe', 'col', 'mex'}
# {'pe', 'col', 'mex'}
