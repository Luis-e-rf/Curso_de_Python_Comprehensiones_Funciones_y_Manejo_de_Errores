# %%
import sys
print(sys.path)

import re
text = 'Mi numero de telefono es 320 123 945, el codigo del pais es 57, mi numero de la suerte es 13'
result = re.findall('[0-9]+', text)
print(result)

import time
timestamp = time.time()
print(timestamp)

local = time.localtime()
result = time.asctime(local)
print(result)

import collections
numbers = [1,1,2,1,2,1,4,5,3,3,21]
counter = collections.Counter(numbers)
print(type(counter))
print(counter)
# Out:
# ['/content', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.9/dist-packages/IPython/extensions', '/root/.ipython']
# ['320', '123', '945', '57', '13']
# 1679373562.863092
# Tue Mar 21 04:39:22 2023
# <class 'collections.Counter'>
# Counter({1: 4, 2: 2, 3: 2, 4: 1, 5: 1, 21: 1})
