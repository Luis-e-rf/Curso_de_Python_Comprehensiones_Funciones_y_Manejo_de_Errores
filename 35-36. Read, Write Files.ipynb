# %%
from google.colab import drive
drive.mount('/content/drive')

file = open('/content/drive/MyDrive/Colab Notebooks/Curso de Python Comprehensions, Funciones y Manejo de Errores/text.txt')
#print(file.read())
# print(file.readline())
# print(file.readline())
# print(file.readline())
# print(file.readline())

for line in file:
  print(line)

file.close()


with open('/content/drive/MyDrive/Colab Notebooks/Curso de Python Comprehensions, Funciones y Manejo de Errores/text.txt', 'r+') as file:
  for line in file:
    print(line)
  file.write('\n\nAgregue nuevas cosas al archivo')
  file.write('\n\nfinal de la linea')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# line 1
#
# line 2
#
# lie 3
#
# asd1
#
# asd2
#
# asd3
#
#
#
# asd5
# line 1
#
# line 2
#
# lie 3
#
# asd1
#
# asd2
#
# asd3
#
#
#
# asd5
